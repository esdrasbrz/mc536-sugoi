# %% [markdown]
# # Análise XQuery

# %% [markdown]
# ## Modelo Conceitual
# ![Modelo Conceitual](../img/conceitual-v4-xpath.png "Title")
#
# ## Modelo Lógico
#
# - **Disease**(*name*, occurrences)
# - **Symptom**(*name*, occurrences)
# - **Cause**(*disease*, *symptom*, occurrences, score)
#     - Chave Estrangeira: *disease* -> **Disease**
#     - Chave Estrangeira: *symptom* -> **Symptom**

# %% [markdown]
# ## Conversão dos CSV de dados para XML
# Reduzido a quantidade de dados consideravelmente para poder realizar as análises no zorba. Apenas 100 doenças e 5 sintomas por doenças foram utilizadas.
#
# ```python
#
# # cria um dicionário de sintomas
# symptoms_dic = {}
# with open('ncomms-symptom.csv', 'r') as fin:
#     symptoms = fin.read().split('\n')[1:]
#
#     for symptom in symptoms:
#         if symptom:
#             name, occurrences = symptom.split('|')
#             symptoms_dic[name] = int(occurrences)
#
# # cria um dicionário de causas
# causes_dic = {}
# with open('ncomms-cause.csv', 'r') as fin:
#     causes = fin.read().split('\n')[1:]
#
#     for cause in causes:
#         if cause:
#             symptom, disease, occurrences, score = cause.split('|')
#
#             if disease not in causes_dic:
#                 causes_dic[disease] = []
#
#             causes_dic[disease].append({
#                 'symptom': symptom,
#                 'occurrences': int(occurrences),
#                 'score': float(score)
#             })
#
#     # limita a quantidade de sintomas por doença
#     for disease in causes_dic:
#         causes_dic[disease].sort(key=lambda k: k['score'], reverse=True)
#         causes_dic[disease] = causes_dic[disease][:5]
#
# xml = '<?xml version="1.0" encoding="UTF-8"?>\n'
# xml += '<diseases>\n'
#
# with open('ncomms-disease.csv', 'r') as fin:
#     diseases = fin.read().split('\n')[1:100]
#
#     for disease in diseases:
#         if disease:
#             name, occurrences = disease.split('|')
#
#             xml += '\t<disease name="%s">\n' % name
#             xml += '\t\t<occurrences>%s</occurrences>\n' % occurrences
#
#             # adiciona os sintomas
#             xml += '\t\t<symptoms>\n'
#             if name in causes_dic:
#                 for symptom in causes_dic[name]:
#                     xml += '\t\t\t<symptom name="%s">\n' % symptom['symptom']
#                     xml += '\t\t\t\t<occurrences>%d</occurrences>\n' % symptom['occurrences']
#                     xml += '\t\t\t\t<score>%f</score>\n' % symptom['score']
#                     xml += '\t\t\t</symptom>\n'
#
#             xml += '\t\t</symptoms>\n'
#
#             xml += '\t</disease>\n'
#
# xml += '</diseases>\n'
#
# # save xml file
# with open('ncomms.xml', 'w') as fout:
#     fout.write(xml)
# ```

# %% [markdown]
# ### Retornar as doenças rotuladas como Diabetes
#
# ```xquery
# let $ncomms := doc('mydoc.xml')
#
# for $i in $ncomms//disease
# where matches($i/@name, 'Diabetes')
# order by $i/occurrences descending
# return $i
# ```
#
# Retorno:
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <disease name="Diabetes Mellitus, Type 2">
#     <occurrences>46242</occurrences>
#     <symptoms>
#         <symptom name="Obesity">
#             <occurrences>4638</occurrences>
#             <score>3861.383836</score>
#         </symptom>
#         <symptom name="Albuminuria">
#             <occurrences>1854</occurrences>
#             <score>3828.670677</score>
#         </symptom>
#         <symptom name="Weight Loss">
#             <occurrences>671</occurrences>
#             <score>671.036040</score>
#         </symptom>
#         <symptom name="Proteinuria">
#             <occurrences>465</occurrences>
#             <score>580.774665</score>
#         </symptom>
#         <symptom name="Weight Gain">
#             <occurrences>390</occurrences>
#             <score>579.808999</score>
#         </symptom>
#     </symptoms>
# </disease>
# <disease name="Diabetes Mellitus">
#     <occurrences>38441</occurrences>
#     <symptoms>
#         <symptom name="Obesity">
#             <occurrences>3255</occurrences>
#             <score>2709.962136</score>
#         </symptom>
#         <symptom name="Albuminuria">
#             <occurrences>327</occurrences>
#             <score>675.283340</score>
#         </symptom>
#         <symptom name="Body Weight">
#             <occurrences>1100</occurrences>
#             <score>377.286632</score>
#         </symptom>
#         <symptom name="Weight Loss">
#             <occurrences>217</occurrences>
#             <score>217.011655</score>
#         </symptom>
#         <symptom name="Proteinuria">
#             <occurrences>170</occurrences>
#             <score>212.326222</score>
#         </symptom>
#     </symptoms>
# </disease>
# <disease name="Diabetes Mellitus, Type 1">
#     <occurrences>37268</occurrences>
#     <symptoms>
#         <symptom name="Albuminuria">
#             <occurrences>1623</occurrences>
#             <score>3351.635658</score>
#         </symptom>
#         <symptom name="Proteinuria">
#             <occurrences>347</occurrences>
#             <score>433.395287</score>
#         </symptom>
#         <symptom name="Obesity">
#             <occurrences>477</occurrences>
#             <score>397.128092</score>
#         </symptom>
#         <symptom name="Birth Weight">
#             <occurrences>206</occurrences>
#             <score>289.868974</score>
#         </symptom>
#         <symptom name="Fetal Macrosomia">
#             <occurrences>86</occurrences>
#             <score>286.957758</score>
#         </symptom>
#     </symptoms>
# </disease>
# <disease name="Diabetes Mellitus, Experimental">
#     <occurrences>19998</occurrences>
#     <symptoms>
#         <symptom name="Body Weight">
#             <occurrences>2268</occurrences>
#             <score>777.896437</score>
#         </symptom>
#         <symptom name="Albuminuria">
#             <occurrences>255</occurrences>
#             <score>526.597100</score>
#         </symptom>
#         <symptom name="Obesity">
#             <occurrences>321</occurrences>
#             <score>267.249722</score>
#         </symptom>
#         <symptom name="Hyperalgesia">
#             <occurrences>90</occurrences>
#             <score>215.469907</score>
#         </symptom>
#         <symptom name="Proteinuria">
#             <occurrences>161</occurrences>
#             <score>201.085422</score>
#         </symptom>
#     </symptoms>
# </disease>
# ```

# %% [markdown]
# ### Retornar as doenças e os sintomas acima da média de score
#
# ```xquery
# let $ncomms := doc('mydoc.xml')
#
# for $i in ($ncomms//disease)
# return
# <disease>
#   <name>{data($i/@name)}</name>
#   <symptoms>
#     <avgscore>{avg($i/symptoms/symptom/score)}</avgscore>
#     {
#       for $j in ($i/symptoms/symptom)
#       where $j[score>avg($i/symptoms/symptom/score)]
#       return $j
#     }
#   </symptoms>
# </disease>
# ```
#
# Retorno (limitado às duas primeiras doenças):
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <disease>
#     <name>Breast Neoplasms</name>
#     <symptoms>
#         <avgscore>396.186838</avgscore>
#         <symptom name="Hot Flashes">
#             <occurrences>191</occurrences>
#             <score>650.490799</score>
#         </symptom>
#     </symptoms>
# </disease>
# <disease>
#     <name>Hypertension</name>
#     <symptoms>
#         <avgscore>1620.9151506</avgscore>
#         <symptom name="Albuminuria">
#             <occurrences>1316</occurrences>
#             <score>2717.654051</score>
#         </symptom>
#         <symptom name="Obesity">
#             <occurrences>2997</occurrences>
#             <score>2495.163294</score>
#         </symptom>
#     </symptoms>
# </disease>
# ```

# %% [markdown]
# ### Retornar as doenças que possuem o sintoma 'Obesity'

# %% [markdown]
# ```xquery
# let $ncomms := doc('mydoc.xml')
#
# for $i in ($ncomms//disease)
# where ($i[symptoms/symptom/@name="Obesity"])
# return <disease>{data($i/@name)}</disease>
# ```
#
# Retorno:
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <disease>Breast Neoplasms</disease><disease>Hypertension</disease><disease>Coronary Artery Disease</disease><disease>Coronary Disease</disease><disease>Prostatic Neoplasms</disease><disease>Obesity</disease><disease>Diabetes Mellitus, Type 2</disease><disease>Kidney Failure, Chronic</disease><disease>Diabetes Mellitus</disease><disease>Diabetes Mellitus, Type 1</disease><disease>Kidney Diseases</disease><disease>Myocardial Ischemia</disease><disease>Colorectal Neoplasms</disease><disease>Carcinoma, Hepatocellular</disease><disease>Liver Diseases</disease><disease>Arteriosclerosis</disease><disease>Liver Cirrhosis</disease><disease>Inflammation</disease><disease>Pregnancy Complications</disease><disease>Diabetes Mellitus, Experimental</disease><disease>Uterine Neoplasms</disease><disease>Esophageal Neoplasms</disease><disease>Psoriasis</disease>
# ```

# %% [markdown]
# ### Retornar a média de 'occurrences' das doenças
#
# ```xquery
# let $ncomms := doc('mydoc.xml')
#
# return avg($ncomms//disease/occurrences)
# ```
#
# Retorno:
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# 33340.515151515152
# ```

# %% [markdown]
# ### Retornar a quantidade de doenças que estão acima da média de 'occurrences'
#
# ```xquery
# let $ncomms := doc('mydoc.xml')
#
# return count($ncomms//disease[occurrences > avg($ncomms//disease/occurrences)])
# ```
#
# Retorno:
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# 32
# ```

# %% [markdown]
# # Análise SPARQL

# %% [markdown]
# Utilizamos os dados do MESH

# %%
%endpoint http://id.nlm.nih.gov/mesh/sparql
%display table
%show all
# Out:
# Endpoint set to: http://id.nlm.nih.gov/mesh/sparql
# Display: table
# Result maximum size: unlimited

# %% [markdown]
# ### Retornar todas as doenças do sistema digestivo

# %%
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX mesh2015: <http://id.nlm.nih.gov/mesh/2015/>
PREFIX mesh2016: <http://id.nlm.nih.gov/mesh/2016/>
PREFIX mesh2017: <http://id.nlm.nih.gov/mesh/2017/>

SELECT DISTINCT ?descriptor ?label
WHERE {
    mesh:D004066 meshv:treeNumber ?treeNum .
    ?childTreeNum meshv:parentTreeNumber+ ?treeNum .
    ?descriptor meshv:treeNumber ?childTreeNum .
    ?descriptor rdfs:label ?label .
}
ORDER BY ?label
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>descriptor</th>
# <th>label</th></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D042101" target="_other">http://id.nlm.nih.gov/mesh/D042101</a></td>
# <td class=val>Acalculous Cholecystitis</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D000126" target="_other">http://id.nlm.nih.gov/mesh/D000126</a></td>
# <td class=val>Achlorhydria</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D065290" target="_other">http://id.nlm.nih.gov/mesh/D065290</a></td>
# <td class=val>Acute-On-Chronic Liver Failure</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D007516" target="_other">http://id.nlm.nih.gov/mesh/D007516</a></td>
# <td class=val>Adenoma, Islet Cell</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D018248" target="_other">http://id.nlm.nih.gov/mesh/D018248</a></td>
# <td class=val>Adenoma, Liver Cell</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D011125" target="_other">http://id.nlm.nih.gov/mesh/D011125</a></td>
# <td class=val>Adenomatous Polyposis Coli</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D000343" target="_other">http://id.nlm.nih.gov/mesh/D000343</a></td>
# <td class=val>Afferent Loop Syndrome</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D016738" target="_other">http://id.nlm.nih.gov/mesh/D016738</a></td>
# <td class=val>Alagille Syndrome</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D000694" target="_other">http://id.nlm.nih.gov/mesh/D000694</a></td>
# <td class=val>Anal Gland Neoplasms</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D017129" target="_other">http://id.nlm.nih.gov/mesh/D017129</a></td>
# <td class=val>Anisakiasis</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D000071056" target="_other">http://id.nlm.nih.gov/mesh/D000071056</a></td>
# <td class=val>Anorectal Malformations</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001004" target="_other">http://id.nlm.nih.gov/mesh/D001004</a></td>
# <td class=val>Anus Diseases</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D001005" target="_other">http://id.nlm.nih.gov/mesh/D001005</a></td>
# <td class=val>Anus Neoplasms</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001006" target="_other">http://id.nlm.nih.gov/mesh/D001006</a></td>
# <td class=val>Anus, Imperforate</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D001063" target="_other">http://id.nlm.nih.gov/mesh/D001063</a></td>
# <td class=val>Appendiceal Neoplasms</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001064" target="_other">http://id.nlm.nih.gov/mesh/D001064</a></td>
# <td class=val>Appendicitis</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D001447" target="_other">http://id.nlm.nih.gov/mesh/D001447</a></td>
# <td class=val>Balantidiasis</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001471" target="_other">http://id.nlm.nih.gov/mesh/D001471</a></td>
# <td class=val>Barrett Esophagus</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D001649" target="_other">http://id.nlm.nih.gov/mesh/D001649</a></td>
# <td class=val>Bile Duct Diseases</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001650" target="_other">http://id.nlm.nih.gov/mesh/D001650</a></td>
# <td class=val>Bile Duct Neoplasms</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D001655" target="_other">http://id.nlm.nih.gov/mesh/D001655</a></td>
# <td class=val>Bile Reflux</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001656" target="_other">http://id.nlm.nih.gov/mesh/D001656</a></td>
# <td class=val>Biliary Atresia</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D001657" target="_other">http://id.nlm.nih.gov/mesh/D001657</a></td>
# <td class=val>Biliary Dyskinesia</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001658" target="_other">http://id.nlm.nih.gov/mesh/D001658</a></td>
# <td class=val>Biliary Fistula</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D001660" target="_other">http://id.nlm.nih.gov/mesh/D001660</a></td>
# <td class=val>Biliary Tract Diseases</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001661" target="_other">http://id.nlm.nih.gov/mesh/D001661</a></td>
# <td class=val>Biliary Tract Neoplasms</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D016776" target="_other">http://id.nlm.nih.gov/mesh/D016776</a></td>
# <td class=val>Blastocystis Infections</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D001765" target="_other">http://id.nlm.nih.gov/mesh/D001765</a></td>
# <td class=val>Blind Loop Syndrome</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D006502" target="_other">http://id.nlm.nih.gov/mesh/D006502</a></td>
# <td class=val>Budd-Chiari Syndrome</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D017675" target="_other">http://id.nlm.nih.gov/mesh/D017675</a></td>
# <td class=val>CREST Syndrome</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D006528" target="_other">http://id.nlm.nih.gov/mesh/D006528</a></td>
# <td class=val>Carcinoma, Hepatocellular</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D018273" target="_other">http://id.nlm.nih.gov/mesh/D018273</a></td>
# <td class=val>Carcinoma, Islet Cell</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D021441" target="_other">http://id.nlm.nih.gov/mesh/D021441</a></td>
# <td class=val>Carcinoma, Pancreatic Ductal</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D016767" target="_other">http://id.nlm.nih.gov/mesh/D016767</a></td>
# <td class=val>Caroli Disease</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D002429" target="_other">http://id.nlm.nih.gov/mesh/D002429</a></td>
# <td class=val>Cecal Diseases</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D002430" target="_other">http://id.nlm.nih.gov/mesh/D002430</a></td>
# <td class=val>Cecal Neoplasms</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D002446" target="_other">http://id.nlm.nih.gov/mesh/D002446</a></td>
# <td class=val>Celiac Disease</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D056486" target="_other">http://id.nlm.nih.gov/mesh/D056486</a></td>
# <td class=val>Chemical and Drug Induced Liver Injury</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D056487" target="_other">http://id.nlm.nih.gov/mesh/D056487</a></td>
# <td class=val>Chemical and Drug Induced Liver Injury, Chronic</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D059269" target="_other">http://id.nlm.nih.gov/mesh/D059269</a></td>
# <td class=val>Chilaiditi Syndrome</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D002761" target="_other">http://id.nlm.nih.gov/mesh/D002761</a></td>
# <td class=val>Cholangitis</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D015209" target="_other">http://id.nlm.nih.gov/mesh/D015209</a></td>
# <td class=val>Cholangitis, Sclerosing</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D002764" target="_other">http://id.nlm.nih.gov/mesh/D002764</a></td>
# <td class=val>Cholecystitis</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D041881" target="_other">http://id.nlm.nih.gov/mesh/D041881</a></td>
# <td class=val>Cholecystitis, Acute</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D041761" target="_other">http://id.nlm.nih.gov/mesh/D041761</a></td>

# %% [markdown]
# ### Doenças altamente similares a 'Hepatitis B' em todos os níveis
#
# ```
# MATCH (d:Disease {name: "Hepatitis B"})-[:VERY_SIMILAR_TO*]-(a:Disease)
# RETURN d, a
# LIMIT 50
# ```
#
# ![Hepatitis B](../img/hepatitis_b.png "Title")

# %% [markdown]
# ### Quais doenças do sistema digestivo são infecções bacterianas

# %%
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX mesh2015: <http://id.nlm.nih.gov/mesh/2015/>
PREFIX mesh2016: <http://id.nlm.nih.gov/mesh/2016/>
PREFIX mesh2017: <http://id.nlm.nih.gov/mesh/2017/>

SELECT DISTINCT ?descriptor ?label
WHERE {
    mesh:D004066 meshv:treeNumber ?treeNum .
    ?childTreeNum meshv:parentTreeNumber+ ?treeNum .
    ?descriptor meshv:broaderDescriptor+ mesh:D001424 .
    ?descriptor meshv:treeNumber ?childTreeNum .
    ?descriptor rdfs:label ?label .
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>descriptor</th>
# <th>label</th></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D004405" target="_other">http://id.nlm.nih.gov/mesh/D004405</a></td>
# <td class=val>Dysentery, Bacillary</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D004761" target="_other">http://id.nlm.nih.gov/mesh/D004761</a></td>
# <td class=val>Enterocolitis, Pseudomembranous</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D008061" target="_other">http://id.nlm.nih.gov/mesh/D008061</a></td>
# <td class=val>Whipple Disease</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D014385" target="_other">http://id.nlm.nih.gov/mesh/D014385</a></td>
# <td class=val>Tuberculosis, Gastrointestinal</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D014386" target="_other">http://id.nlm.nih.gov/mesh/D014386</a></td>
# <td class=val>Tuberculosis, Hepatic</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D014395" target="_other">http://id.nlm.nih.gov/mesh/D014395</a></td>
# <td class=val>Peritonitis, Tuberculous</td></tr></table><div class="tinfo">Total: 6, Shown: 6</div></div>

# %% [markdown]
# ### Relações entre sintomas de infecções bacterianas do sistema digestivo
#
# ```
# MATCH (a:Disease {name: "Dysentery, Bacillary"})-[:CAUSES]->(s:Symptom)
# MATCH (b:Disease {name: "Tuberculosis, Gastrointestinal"})-[:CAUSES]->(s)
# MATCH (c:Disease {name: "Enterocolitis, Pseudomembranous"})-[:CAUSES]->(s)
# MATCH (d:Disease {name: "Whipple Disease"})-[:CAUSES]->(s)
# return a, b, c, d, s
# ```
#
# ![Infecções Bacterianas](../img/infeccao_bacteriana_digestivo.png "Title")

# %% [markdown]
# ### Quais doenças do sistema digestivo são intestinais

# %%
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX mesh2015: <http://id.nlm.nih.gov/mesh/2015/>
PREFIX mesh2016: <http://id.nlm.nih.gov/mesh/2016/>
PREFIX mesh2017: <http://id.nlm.nih.gov/mesh/2017/>

SELECT DISTINCT ?descriptor ?label
WHERE {
    mesh:D004066 meshv:treeNumber ?treeNum .
    ?childTreeNum meshv:parentTreeNumber+ ?treeNum .
    ?descriptor meshv:broaderDescriptor mesh:D007410 .
    ?descriptor meshv:treeNumber ?childTreeNum .
    ?descriptor rdfs:label ?label .
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>descriptor</th>
# <th>label</th></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D002429" target="_other">http://id.nlm.nih.gov/mesh/D002429</a></td>
# <td class=val>Cecal Diseases</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D003108" target="_other">http://id.nlm.nih.gov/mesh/D003108</a></td>
# <td class=val>Colonic Diseases</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D004378" target="_other">http://id.nlm.nih.gov/mesh/D004378</a></td>
# <td class=val>Duodenal Diseases</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D004403" target="_other">http://id.nlm.nih.gov/mesh/D004403</a></td>
# <td class=val>Dysentery</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D004760" target="_other">http://id.nlm.nih.gov/mesh/D004760</a></td>
# <td class=val>Enterocolitis</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D015212" target="_other">http://id.nlm.nih.gov/mesh/D015212</a></td>
# <td class=val>Inflammatory Bowel Diseases</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D011504" target="_other">http://id.nlm.nih.gov/mesh/D011504</a></td>
# <td class=val>Protein-Losing Enteropathies</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D012002" target="_other">http://id.nlm.nih.gov/mesh/D012002</a></td>
# <td class=val>Rectal Diseases</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D044483" target="_other">http://id.nlm.nih.gov/mesh/D044483</a></td>
# <td class=val>Intestinal Polyposis</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D007077" target="_other">http://id.nlm.nih.gov/mesh/D007077</a></td>
# <td class=val>Ileal Diseases</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D007412" target="_other">http://id.nlm.nih.gov/mesh/D007412</a></td>
# <td class=val>Intestinal Fistula</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D007416" target="_other">http://id.nlm.nih.gov/mesh/D007416</a></td>
# <td class=val>Intestinal Perforation</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D007579" target="_other">http://id.nlm.nih.gov/mesh/D007579</a></td>
# <td class=val>Jejunal Diseases</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D008641" target="_other">http://id.nlm.nih.gov/mesh/D008641</a></td>
# <td class=val>Mesenteric Vascular Occlusion</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D011006" target="_other">http://id.nlm.nih.gov/mesh/D011006</a></td>
# <td class=val>Pneumatosis Cystoides Intestinalis</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D015043" target="_other">http://id.nlm.nih.gov/mesh/D015043</a></td>
# <td class=val>Zollinger-Ellison Syndrome</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D007411" target="_other">http://id.nlm.nih.gov/mesh/D007411</a></td>
# <td class=val>Intestinal Diseases, Parasitic</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D004751" target="_other">http://id.nlm.nih.gov/mesh/D004751</a></td>
# <td class=val>Enteritis</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D007409" target="_other">http://id.nlm.nih.gov/mesh/D007409</a></td>
# <td class=val>Intestinal Atresia</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D007414" target="_other">http://id.nlm.nih.gov/mesh/D007414</a></td>
# <td class=val>Intestinal Neoplasms</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D007415" target="_other">http://id.nlm.nih.gov/mesh/D007415</a></td>
# <td class=val>Intestinal Obstruction</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D008286" target="_other">http://id.nlm.nih.gov/mesh/D008286</a></td>
# <td class=val>Malabsorption Syndromes</td></tr><tr class=odd><td class=val><a href="http://id.nlm.nih.gov/mesh/D065666" target="_other">http://id.nlm.nih.gov/mesh/D065666</a></td>
# <td class=val>Mesenteric Ischemia</td></tr><tr class=even><td class=val><a href="http://id.nlm.nih.gov/mesh/D019053" target="_other">http://id.nlm.nih.gov/mesh/D019053</a></td>
# <td class=val>HIV Enteropathy</td></tr></table><div class="tinfo">Total: 24, Shown: 24</div></div>
